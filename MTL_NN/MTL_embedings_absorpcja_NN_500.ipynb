# %% [markdown]
# ### **Sieć neuronowa MTL na reprezentacji fingerprint - zestaw 1 - Absorpcja**

# %% [markdown]
# Wykorzystana reprezentacja: **ECFP4**
#
# Lista endpointów:
#
#
# 1. Caco-2 (Wang)
# 2. Lipophilicity (AstraZeneca)
# 3. Solubility (AqSolDB)
# 4. HIA (Hou)
# 5. AMES Mutagenicity

# %% [markdown]
# Wyniki dla STL:

# %%
# !pip install rdkit
# !pip install pandas numpy scikit-learn -U
# !pip install pytdc --no-dependencies
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (2026.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.4.6)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (3.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.4.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pytdc in /usr/local/lib/python3.12/dist-packages (1.1.15)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.12/dist-packages (0.18.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_folder = "/content/drive/MyDrive/mldd_data" #folder z zapisanymi zestawami danych aby umożliwić porównanie danych na dokładnie tych samych zestawach dla każdego modelu

#data_folder = "/content/drive/MyDrive/MLDD - ADMET/data_splits"

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from tdc.single_pred import ADME
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, roc_auc_score, accuracy_score, f1_score

# %%
class ADMETDescriptorFeaturizer:
    def __init__(self, y_column, smiles_col='Drug'):
        self.y_column = y_column
        self.smiles_col = smiles_col
        self.feature_names = [
            'MW', 'LogP', 'HBD', 'HBA', 'TPSA',
            'RotatableBonds', 'AromaticRings', 'HeavyAtoms',
            'MolMR', 'FractionCSP3'
        ]
        self.scaler = StandardScaler()

    def __call__(self, df, fit_scaler=True):
        features = []
        labels = []

        for i, row in df.iterrows():
            smiles = row[self.smiles_col]
            y = row[self.y_column] if self.y_column in df.columns else np.nan
            mol = Chem.MolFromSmiles(str(smiles)) if pd.notna(smiles) else None

            if mol:
                desc_vector = [
                    Descriptors.MolWt(mol),
                    Descriptors.MolLogP(mol),
                    Lipinski.NumHDonors(mol),
                    Lipinski.NumHAcceptors(mol),
                    Descriptors.TPSA(mol),
                    Lipinski.NumRotatableBonds(mol),
                    Lipinski.NumAromaticRings(mol),
                    Descriptors.HeavyAtomCount(mol),
                    Descriptors.MolMR(mol),
                    Lipinski.FractionCSP3(mol)
                ]
            else:
                # Wstawiamy wektor zer o długości 10, jeśli cząsteczka jest błędna
                desc_vector = [0.0] * len(self.feature_names)

            features.append(desc_vector)
            labels.append(y)

        features_array = np.array(features)

        if fit_scaler:
            normalized_features = self.scaler.fit_transform(features_array)
        else:
            normalized_features = self.scaler.transform(features_array)

        return normalized_features, np.array(labels).reshape(-1, 1)

# %%
# DEFINICJA SIECI NEURONOWEJ

class AdmetEncoder(nn.Module):
    def __init__(self, input_dim, hidden_dim=512, dropout=0.2):
        super().__init__()
        self.main = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout)
        )
        self.res_layer = nn.Linear(hidden_dim, hidden_dim)

    def forward(self, x):
        x = self.main(x)
        return torch.relu(x + self.res_layer(x))


class MTL_NN_Hybrid(nn.Module):
    def __init__(self, input_dim, reg_tasks, class_tasks, hidden_dim=512):
        """
        reg_tasks: lista nazw zadań regresyjnych (np. ['Lipophilicity', 'Solubility'])
        class_tasks: lista nazw zadań klasyfikacyjnych (np. ['BBB', 'Ames'])
        """
        super().__init__()
        self.encoder = AdmetEncoder(input_dim, hidden_dim)
        self.reg_tasks = reg_tasks
        self.class_tasks = class_tasks

        # Słowniki głowic dla każdego typu zadania
        #Pozwala zapisać wiele warstw Linear i nazwać je tak, jak nazywają się Twoje zadania.
        self.reg_heads = nn.ModuleDict({
            task: nn.Linear(hidden_dim, 1) for task in reg_tasks
        })
        self.class_heads = nn.ModuleDict({
            task: nn.Linear(hidden_dim, 1) for task in class_tasks
        })

    def forward(self, x):
        shared_features = self.encoder(x) #wspólny enkoder
        results = {}

        # Procesowanie zadań regresyjnych
        for task in self.reg_tasks:
            results[task] = self.reg_heads[task](shared_features)

        # Procesowanie zadań klasyfikacyjnych
        for task in self.class_tasks:
            # results[task] = torch.sigmoid(self.class_heads[task](shared_features))
            results[task] = self.class_heads[task](shared_features)

        #print(results)
        return results #Zwracając słownik:{'Caco2_Wang': 1.2, 'Lipophilicity_AZ': 0.5} masz absolutną pewność, który wynik dotyczy którego badania.

# %%
# --- STL REGRESOR ---
class STL_NN_Regressor(nn.Module):
    def __init__(self, input_dim, hidden_dim=512):
        super().__init__()
        self.encoder = AdmetEncoder(input_dim, hidden_dim)
        self.head = nn.Linear(hidden_dim, 1) # Wynik liniowy (dowolna liczba)

    def forward(self, x):
        return self.head(self.encoder(x))

# --- STL KLASYFIKATOR ---
class STL_NN_Classifier(nn.Module):
    def __init__(self, input_dim, hidden_dim=512):
        super().__init__()
        self.encoder = AdmetEncoder(input_dim, hidden_dim)
        self.head = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        # Sigmoid zamienia wynik na prawdopodobieństwo (0-1)
        return torch.sigmoid(self.head(self.encoder(x)))

  #=============================

# %%
def train_MTL_hybrid_wl_sum(X_train_np, X_test_np, y_train_dict, y_test_dict, reg_tasks, class_tasks):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # --- 1. Normalizacja (osobny skaler dla każdego zadania regresyjnego) ---
    scalers = {}
    y_train_tensors = {}
    y_test_tensors = {}

    for task in reg_tasks:
        scalers[task] = StandardScaler()
        # Wyciągamy dane i maskujemy NaN, aby skaler zadziałał
        train_vals = y_train_dict[task].reshape(-1, 1)
        mask = ~np.isnan(train_vals).flatten()

        y_train_scaled = np.full_like(train_vals, np.nan)
        if mask.any():
            y_train_scaled[mask] = scalers[task].fit_transform(train_vals[mask])

        y_train_tensors[task] = torch.FloatTensor(y_train_scaled).to(device)
        # Testowe przesyłamy w oryginale (skalujemy tylko przy ewaluacji dla wygody)
        y_test_tensors[task] = torch.FloatTensor(y_test_dict[task].reshape(-1, 1)).to(device)

    for task in class_tasks:
        # Klasyfikacja nie wymaga skalowania
        y_train_tensors[task] = torch.FloatTensor(y_train_dict[task].reshape(-1, 1)).to(device)
        y_test_tensors[task] = torch.FloatTensor(y_test_dict[task].reshape(-1, 1)).to(device)

    X_train_t = torch.FloatTensor(X_train_np).to(device)
    X_test_t = torch.FloatTensor(X_test_np).to(device)

    # --- 2. Model i Optymalizator ---
    # Bierzemy wymiar wejściowy z liczby kolumn X_train_np
    model = MTL_NN_Hybrid(input_dim=X_train_np.shape[1], reg_tasks=reg_tasks, class_tasks=class_tasks).to(device) #zmienione
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion_reg = nn.MSELoss(reduction='none') # 'none' pozwala nam ręcznie obsłużyć NaN
    criterion_cls = nn.BCEWithLogitsLoss(reduction='none')

    print("\n--- START TRENINGU (Multi-Task) ---")
    model.train()
    for epoch in range(500):
        optimizer.zero_grad()
        outputs = model(X_train_t)
        total_loss = 0

        # Sumujemy straty ze wszystkich zadań, ignorując NaN
        for task in reg_tasks:
            target = y_train_tensors[task]
            mask = ~torch.isnan(target)
            if mask.any():
                loss = criterion_reg(outputs[task][mask], target[mask]).mean()
                total_loss += loss

        for task in class_tasks:
            target = y_train_tensors[task]
            mask = ~torch.isnan(target)
            if mask.any():
                loss = criterion_cls(outputs[task][mask], target[mask]).mean()
                total_loss += loss

        total_loss.backward()
        optimizer.step()

        if epoch % 20 == 0:
            print(f"  Epoka {epoch:3d} | Total Loss: {total_loss.item():.4f}")

    # --- 3. Ewaluacja ---
    print("\n--- EWALUACJA ---")
    model.eval()
    all_metrics = {"reg_tasks": {}, "class_tasks": {}}

    with torch.no_grad():
        preds_dict = model(X_test_t)

        for task in reg_tasks:
            y_true = y_test_dict[task].flatten()
            mask = ~np.isnan(y_true)
            if not mask.any(): continue

            # Odwracamy skalowanie
            p_scaled = preds_dict[task].cpu().numpy()
            p_unscaled = scalers[task].inverse_transform(p_scaled).flatten()


            mse = mean_squared_error(y_true[mask], p_unscaled[mask])
            mae = mean_absolute_error(y_true[mask], p_unscaled[mask]) # <-- Dodaj tę linię
            r2 = r2_score(y_true[mask], p_unscaled[mask])

            all_metrics["reg_tasks"][task] = {
               "rmse": np.sqrt(mse),
               "mae": mae,  # <-- I tę linię
               "r2": r2
             }

        for task in class_tasks:
            y_true = y_test_dict[task].flatten()
            mask = ~np.isnan(y_true)
            if not mask.any(): continue

            p_probs  = torch.sigmoid(preds_dict[task]).cpu().numpy().flatten()
            p_labels = (p_probs[mask] > 0.5).astype(int)
            try:
                auroc = roc_auc_score(y_true[mask], p_probs[mask])
            except ValueError:
                auroc = 0.5

            all_metrics["class_tasks"][task] = {
                "accuracy": accuracy_score(y_true[mask], p_labels),
                "f1":       f1_score(y_true[mask], p_labels),
                "auroc":    auroc,
            }

    return all_metrics

# %%
def train_MTL_hybrid_uniform_average(X_train_np, X_test_np, y_train_dict, y_test_dict, reg_tasks, class_tasks):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    scalers = {}
    y_train_tensors = {}
    y_test_tensors = {}

    for task in reg_tasks:
        scalers[task] = StandardScaler()
        train_vals = y_train_dict[task].reshape(-1, 1)
        mask = ~np.isnan(train_vals).flatten()

        y_train_scaled = np.full_like(train_vals, np.nan)
        if mask.any():
            y_train_scaled[mask] = scalers[task].fit_transform(train_vals[mask])

        y_train_tensors[task] = torch.FloatTensor(y_train_scaled).to(device)
        y_test_tensors[task] = torch.FloatTensor(y_test_dict[task].reshape(-1, 1)).to(device)

    for task in class_tasks:
        y_train_tensors[task] = torch.FloatTensor(y_train_dict[task].reshape(-1, 1)).to(device)
        y_test_tensors[task] = torch.FloatTensor(y_test_dict[task].reshape(-1, 1)).to(device)

    X_train_t = torch.FloatTensor(X_train_np).to(device)
    X_test_t = torch.FloatTensor(X_test_np).to(device)

    model = MTL_NN_Hybrid(input_dim=X_train_np.shape[1], reg_tasks=reg_tasks, class_tasks=class_tasks).to(device) #zmienione
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion_reg = nn.MSELoss(reduction='none') # 'none' pozwala nam ręcznie obsłużyć NaN
    criterion_cls = nn.BCEWithLogitsLoss(reduction='none')


    print("\n--- START TRENINGU (Multi-Task - Uniform Average) ---")
    model.train()
    for epoch in range(500):
        optimizer.zero_grad()
        outputs = model(X_train_t)

        task_losses = []

        for task in reg_tasks:
            target = y_train_tensors[task]
            mask = ~torch.isnan(target)
            if mask.any():
                loss = criterion_reg(outputs[task][mask], target[mask]).mean()
                task_losses.append(loss)

        for task in class_tasks:
            target = y_train_tensors[task]
            mask = ~torch.isnan(target)
            if mask.any():
                loss = criterion_cls(outputs[task][mask], target[mask]).mean()
                task_losses.append(loss)

        if task_losses:
            total_loss = torch.stack(task_losses).mean() # Uniform average
        else:
            total_loss = torch.tensor(0.0, device=device, requires_grad=True)

        total_loss.backward()
        optimizer.step()

        if epoch % 20 == 0:
            print(f"  Epoka {epoch:3d} | Total Loss: {total_loss.item():.4f}")

    print("\n--- EWALUACJA ---")
    model.eval()
    all_metrics = {"reg_tasks": {}, "class_tasks": {}}

    with torch.no_grad():
        preds_dict = model(X_test_t)

        for task in reg_tasks:
            y_true = y_test_dict[task].flatten()
            mask = ~np.isnan(y_true)
            if not mask.any(): continue

            p_scaled = preds_dict[task].cpu().numpy()
            p_unscaled = scalers[task].inverse_transform(p_scaled).flatten()

            mse = mean_squared_error(y_true[mask], p_unscaled[mask])
            mae = mean_absolute_error(y_true[mask], p_unscaled[mask])
            r2 = r2_score(y_true[mask], p_unscaled[mask])

            all_metrics["reg_tasks"][task] = {
               "rmse": np.sqrt(mse),
               "mae": mae,
               "r2": r2
             }

        for task in class_tasks:
            y_true = y_test_dict[task].flatten()
            mask = ~np.isnan(y_true)
            if not mask.any(): continue

            p_probs  = torch.sigmoid(preds_dict[task]).cpu().numpy().flatten()
            p_labels = (p_probs[mask] > 0.5).astype(int)
            try:
                auroc = roc_auc_score(y_true[mask], p_probs[mask])
            except ValueError:
                auroc = 0.5

            all_metrics["class_tasks"][task] = {
                "accuracy": accuracy_score(y_true[mask], p_labels),
                "f1":       f1_score(y_true[mask], p_labels),
                "auroc":    auroc,
            }

    return all_metrics

# %%
def train_MTL_hybrid_uncertainty_weighting(X_train_np, X_test_np, y_train_dict, y_test_dict, reg_tasks, class_tasks):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    scalers = {}
    y_train_tensors = {}
    y_test_tensors = {}

    for task in reg_tasks:
        scalers[task] = StandardScaler()
        train_vals = y_train_dict[task].reshape(-1, 1)
        mask = ~np.isnan(train_vals).flatten()

        y_train_scaled = np.full_like(train_vals, np.nan)
        if mask.any():
            y_train_scaled[mask] = scalers[task].fit_transform(train_vals[mask])

        y_train_tensors[task] = torch.FloatTensor(y_train_scaled).to(device)
        y_test_tensors[task] = torch.FloatTensor(y_test_dict[task].reshape(-1, 1)).to(device)

    for task in class_tasks:
        y_train_tensors[task] = torch.FloatTensor(y_train_dict[task].reshape(-1, 1)).to(device)
        y_test_tensors[task] = torch.FloatTensor(y_test_dict[task].reshape(-1, 1)).to(device)

    X_train_t = torch.FloatTensor(X_train_np).to(device)
    X_test_t = torch.FloatTensor(X_test_np).to(device)

    model = MTL_NN_Hybrid(input_dim=X_train_np.shape[1], reg_tasks=reg_tasks, class_tasks=class_tasks).to(device) #zmienione

    # Learnable parameters for task uncertainty
    log_vars = nn.ParameterDict()
    for task in reg_tasks + class_tasks:
        log_vars[task] = nn.Parameter(torch.zeros(1, device=device)) # Initialize log_sigma_sq to 0


    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion_reg = nn.MSELoss(reduction='none') # 'none' pozwala nam ręcznie obsłużyć NaN
    criterion_cls = nn.BCEWithLogitsLoss(reduction='none')


    print("\n--- START TRENINGU (Multi-Task - Uncertainty Weighting) ---")
    model.train()
    for epoch in range(500):
        optimizer.zero_grad()
        outputs = model(X_train_t)
        total_loss = 0

        for task in reg_tasks:
            target = y_train_tensors[task]
            mask = ~torch.isnan(target)
            if mask.any():
                loss = criterion_reg(outputs[task][mask], target[mask])
                precision = torch.exp(-log_vars[task])
                total_loss += torch.mean(0.5 * precision * loss + 0.5 * log_vars[task])

        for task in class_tasks:
            target = y_train_tensors[task]
            mask = ~torch.isnan(target)
            if mask.any():
                loss = criterion_cls(outputs[task][mask], target[mask])
                precision = torch.exp(-log_vars[task])
                total_loss += torch.mean(precision * loss + 0.5 * log_vars[task])

        total_loss.backward()
        optimizer.step()

        if epoch % 20 == 0:
            print(f"  Epoka {epoch:3d} | Total Loss: {total_loss.item():.4f}")
            # print(f"    Log_vars: {{ {', '.join([f'{t}: {log_vars[t].item():.2f}' for t in log_vars])} }}")

    print("\n--- EWALUACJA ---")
    model.eval()
    all_metrics = {"reg_tasks": {}, "class_tasks": {}}

    with torch.no_grad():
        preds_dict = model(X_test_t)

        for task in reg_tasks:
            y_true = y_test_dict[task].flatten()
            mask = ~np.isnan(y_true)
            if not mask.any(): continue

            p_scaled = preds_dict[task].cpu().numpy()
            p_unscaled = scalers[task].inverse_transform(p_scaled).flatten()

            mse = mean_squared_error(y_true[mask], p_unscaled[mask])
            mae = mean_absolute_error(y_true[mask], p_unscaled[mask])
            r2 = r2_score(y_true[mask], p_unscaled[mask])

            all_metrics["reg_tasks"][task] = {
               "rmse": np.sqrt(mse),
               "mae": mae,
               "r2": r2
             }

        for task in class_tasks:
            y_true = y_test_dict[task].flatten()
            mask = ~np.isnan(y_true)
            if not mask.any(): continue

            p_probs  = torch.sigmoid(preds_dict[task]).cpu().numpy().flatten()
            p_labels = (p_probs[mask] > 0.5).astype(int)
            try:
                auroc = roc_auc_score(y_true[mask], p_probs[mask])
            except ValueError:
                auroc = 0.5

            all_metrics["class_tasks"][task] = {
                "accuracy": accuracy_score(y_true[mask], p_labels),
                "f1":       f1_score(y_true[mask], p_labels),
                "auroc":    auroc,
            }

    return all_metrics

# %%
import pickle

def load_split_pickle(dataset_name):
    filepath = f"{data_folder}/{dataset_name}_split.pkl"

    with open(filepath, "rb") as f:
        split = pickle.load(f)

    return split["train"], split["test"]

# %%
def print_metrics(metrics, task='classification', weight_loss_func_name=None):
    print(f"\n{'='*40}")
    if weight_loss_func_name: # Check if func_name is provided and not None
        print(f"  Loss Weighting: {weight_loss_func_name}")
        print(f"{'='*40}")
    if task == 'classification':
        print(f"  Accuracy : {metrics['test_metrics']['accuracy']:.4f}")
        print(f"  F1       : {metrics['test_metrics']['f1']:.4f}")
        print(f"  AUROC    : {metrics['test_metrics']['auroc']:.4f}")
    else:
        print(f"  RMSE     : {metrics['test_metrics']['rmse']:.4f}")
        print(f"  MAE      : {metrics['test_metrics']['mae']:.4f}")
        print(f"  R²       : {metrics['test_metrics']['r2']:.4f}")
    print(f"{'='*40}\n")


def save_metrics(metrics, dataset_name, filepath, task='classification', weight_loss_func_name=None, endpoint_group_name=None):
    with open(filepath, 'a') as f:
        f.write(f"\n{'='*40}\n")
        f.write(f"Endpoint    : {dataset_name}\n")
        if endpoint_group_name:
            f.write(f"Tasks       : {endpoint_group_name}\n")
        if weight_loss_func_name:
            f.write(f"Loss Weighting: {weight_loss_func_name}\n")
        f.write(f"{'='*40}\n")
        if task == 'classification':
            f.write(f"  Accuracy : {metrics['test_metrics']['accuracy']:.4f}\n")
            f.write(f"  F1       : {metrics['test_metrics']['f1']:.4f}\n")
            f.write(f"  AUROC    : {metrics['test_metrics']['auroc']:.4f}\n")
        else:
            f.write(f"  RMSE     : {metrics['test_metrics']['rmse']:.4f}\n")
            f.write(f"  MAE      : {metrics['test_metrics']['mae']:.4f}\n")
            f.write(f"  R²       : {metrics['test_metrics']['r2']:.4f}\n")
        f.write(f"{'='*40}\n")

# %%
import pandas as pd

def prepare_mtl_data_final(df_list, task_names, featurizer, fit_scaler=True):
    # 1. Zebranie wszystkich unikalnych struktur
    all_drugs = set()
    for df in df_list:
        valid = df['Drug'].dropna().astype(str).unique()
        all_drugs.update(valid)

    # 2. Walidacja cząsteczek przez RDKit przed stworzeniem master_list
    safe_master_list = []
    for drug in sorted(list(all_drugs)):
        mol = Chem.MolFromSmiles(drug)
        if mol: safe_master_list.append(drug)

    drug_to_idx = {drug: i for i, drug in enumerate(safe_master_list)}
    n_samples = len(safe_master_list)

    # 3. Generowanie X (tylko dla poprawnych cząsteczek)
    df_temp = pd.DataFrame({'Drug': safe_master_list})
    # TUTAJ JEST ZMIANA: dodajemy przekazanie parametru fit_scaler
    X_features, _ = featurizer(df_temp, fit_scaler=fit_scaler)

    # Sprawdzenie czy X zawiera NaN
    if np.isnan(X_features).any():
        X_features = np.nan_to_num(X_features)

    # 4. Mapowanie etykiet y
    y_dict = {}
    for df, task in zip(df_list, task_names):
        y_vec = np.full((n_samples, 1), np.nan, dtype=np.float32)
        mapping = dict(zip(df['Drug'].astype(str), df['Y']))

        for drug, val in mapping.items():
            if drug in drug_to_idx and not pd.isna(val):
                y_vec[drug_to_idx[drug]] = val
        y_dict[task] = y_vec

    return X_features, y_dict

# %%
def prepare_mtl_data_embeddings(df_list, task_names, dataset_names):
    """
    df_list: lista DataFrame ze splitów (np. [train_caco2, train_lipo])
    task_names: lista nazw zadań w modelu (np. ['Caco2_Wang', 'Lipophilicity_AZ'])
    dataset_names: lista nazw zbiorów odpowiadająca nazwom plików z embeddingami (np. ['Caco2_Wang', 'Lipophilicity_AstraZeneca'])
    """
    # 1. Zebranie wszystkich unikalnych struktur SMILES z przekazanych splitów
    all_drugs = set()
    for df in df_list:
        valid = df['Drug'].dropna().astype(str).unique()
        all_drugs.update(valid)

    # 2. Wczytanie embeddingów ze wszystkich powiązanych plików CSV dla danej konfiguracji
    # Budujemy jeden zbiorczy słownik mapujący Drug (SMILES) -> wektor embeddingu
    drug_to_emb = {}
    for d_name in dataset_names:
        file_path = f"{data_folder}/{d_name}_MoLFormer_embeddings.csv"
        try:
            emb_df = pd.read_csv(file_path)
            feature_cols = [c for c in emb_df.columns if c.startswith('emb_')]
            for _, row in emb_df.iterrows():
                drug_to_emb[str(row['Drug'])] = row[feature_cols].values.astype(np.float32)
        except Exception as e:
            print(f"Błąd podczas ładowania embeddingów dla {d_name}: {e}")

    # 3. Filtrowanie master_list tylko do cząsteczek, które posiadają embeddingi
    safe_master_list = [drug for drug in sorted(list(all_drugs)) if drug in drug_to_emb]
    drug_to_idx = {drug: i for i, drug in enumerate(safe_master_list)}
    n_samples = len(safe_master_list)

    # 4. Tworzenie macierzy X_features z embeddingów
    emb_dim = len(next(iter(drug_to_emb.values()))) if drug_to_emb else 768
    X_features = np.zeros((n_samples, emb_dim), dtype=np.float32)
    for i, drug in enumerate(safe_master_list):
        X_features[i] = drug_to_emb[drug]

    # 5. Mapowanie etykiet y (dokładnie tak samo jak w wersji z deskryptorami)
    y_dict = {}
    for df, task in zip(df_list, task_names):
        y_vec = np.full((n_samples, 1), np.nan, dtype=np.float32)
        mapping = dict(zip(df['Drug'].astype(str), df['Y']))

        for drug, val in mapping.items():
            if drug in drug_to_idx and not pd.isna(val):
                y_vec[drug_to_idx[drug]] = val
        y_dict[task] = y_vec

    return X_features, y_dict

# %%
# # --- KONFIGURACJA I URUCHOMIENIE ---

# reg_tasks = ['Caco2_Wang', 'Lipophilicity_AZ', 'Solubility_AqSolDB']
# class_tasks = ['HIA_Hou']
# filepath = "mtl_results_absorpcja_embeddings.txt"

# # Definiujemy pełną listę nazw dla 4 plików z embeddingami
# dataset_names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca', 'AqSolDB', 'HIA_Hou']

# # 1. Ładowanie danych
# train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
# train_lipo,  test_lipo  = load_split_pickle('Lipophilicity_AstraZeneca')
# train_sol,   test_sol   = load_split_pickle('Solubility_AqSolDB')
# train_hia,   test_hia   = load_split_pickle('HIA_Hou')

# # 2. Przygotowanie danych MTL za pomocą embeddingów
# X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_lipo, train_sol, train_hia], reg_tasks + class_tasks, dataset_names)
# X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2,  test_lipo,  test_sol,  test_hia],  reg_tasks + class_tasks, dataset_names)

# loss_schemes = [
#     (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
#     (train_MTL_hybrid_uniform_average, "Uniform Average"),
#     (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
# ]

# # Pętla ucząca (loss_schemes) pozostaje całkowicie BEZ ZMIAN
# for train_func, scheme_name in loss_schemes:
#     results = train_func(
#         X_train_mtl,
#         X_test_mtl,
#         y_train_dict,
#         y_test_dict,
#         reg_tasks,
#         class_tasks=class_tasks
#     )

#     print("\n" + "="*40)
#     print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
#     print("="*40)

#     endpoint_group = str(reg_tasks + class_tasks)

#     for task_name, task_metrics in results['reg_tasks'].items():
#         formatted_wrapper = {"test_metrics": task_metrics}
#         print(f"\nWyniki dla zadania (Regresja): {task_name}")
#         print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
#         save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

#     for task_name, task_metrics in results['class_tasks'].items():
#         formatted_wrapper = {"test_metrics": task_metrics}
#         print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
#         print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
#         save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

# print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")

# %% [markdown]
# # Test1: Caco-2 (Wang) + Lipophilicity (Astra Zeneca)

# %% [markdown]
# Test pierwszy sprawdzający czy Lipophilicity (42000 związków) pomoże związanemu z nim CaCo-2 (Wang). Sprawdzamy czy MTL da lepsze wyniki niż STL.

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang', 'Lipophilicity_AZ']
class_tasks = [] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca']

# 1. Ładowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_lipo], reg_tasks, dataset_names)
X_test_mtl, y_test_dict = prepare_mtl_data_embeddings([test_caco2, test_lipo], reg_tasks, dataset_names)

loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 2.8780
#   Epoka  20 | Total Loss: 1.1980
#   Epoka  40 | Total Loss: 0.8685
#   Epoka  60 | Total Loss: 0.6793
#   Epoka  80 | Total Loss: 0.5256
#   Epoka 100 | Total Loss: 0.3951
#   Epoka 120 | Total Loss: 0.3026
#   Epoka 140 | Total Loss: 0.2440
#   Epoka 160 | Total Loss: 0.1793
#   Epoka 180 | Total Loss: 0.1430
#   Epoka 200 | Total Loss: 0.1167
#   Epoka 220 | Total Loss: 0.1145
#   Epoka 240 | Total Loss: 0.0843
#   Epoka 260 | Total Loss: 0.0771
#   Epoka 280 | Total Loss: 0.0702
#   Epoka 300 | Total Loss: 0.0620
#   Epoka 320 | Total Loss: 0.0576
#   Epoka 340 | Total Loss: 0.0535
#   Epoka 360 | Total Loss: 0.0542
#   Epoka 380 | Total Loss: 0.0489
#   Epoka 400 | Total Loss: 0.0488
#   Epoka 420 | Total Loss: 0.0480
#   Epoka 440 | Total Loss: 0.0430
#   Epoka 460 | Total Loss: 0.0390
#   Epoka 480 | Total Loss: 0.0506
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.4822
#   MAE      : 0.3880
#   R²       : 0.6339
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.7261
#   MAE      : 0.5603
#   R²       : 0.6432
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 1.1599
#   Epoka  20 | Total Loss: 0.6416
#   Epoka  40 | Total Loss: 0.4553
#   Epoka  60 | Total Loss: 0.3573
#   Epoka  80 | Total Loss: 0.2721
#   Epoka 100 | Total Loss: 0.1933
#   Epoka 120 | Total Loss: 0.1407
#   Epoka 140 | Total Loss: 0.1022
#   Epoka 160 | Total Loss: 0.0801
#   Epoka 180 | Total Loss: 0.0658
#   Epoka 200 | Total Loss: 0.0502
#   Epoka 220 | Total Loss: 0.0478
#   Epoka 240 | Total Loss: 0.0419
#   Epoka 260 | Total Loss: 0.0360
#   Epoka 280 | Total Loss: 0.0325
#   Epoka 300 | Total Loss: 0.0308
#   Epoka 320 | Total Loss: 0.0285
#   Epoka 340 | Total Loss: 0.0283
#   Epoka 360 | Total Loss: 0.0304
#   Epoka 380 | Total Loss: 0.0241
#   Epoka 400 | Total Loss: 0.0233
#   Epoka 420 | Total Loss: 0.0235
#   Epoka 440 | Total Loss: 0.0225
#   Epoka 460 | Total Loss: 0.0221
#   Epoka 480 | Total Loss: 0.0196
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4990
#   MAE      : 0.3843
#   R²       : 0.6080
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.7349
#   MAE      : 0.5616
#   R²       : 0.6344
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 1.3191
#   Epoka  20 | Total Loss: 0.6333
#   Epoka  40 | Total Loss: 0.4242
#   Epoka  60 | Total Loss: 0.3218
#   Epoka  80 | Total Loss: 0.2437
#   Epoka 100 | Total Loss: 0.1727
#   Epoka 120 | Total Loss: 0.1256
#   Epoka 140 | Total Loss: 0.0966
#   Epoka 160 | Total Loss: 0.0753
#   Epoka 180 | Total Loss: 0.0611
#   Epoka 200 | Total Loss: 0.0503
#   Epoka 220 | Total Loss: 0.0518
#   Epoka 240 | Total Loss: 0.0399
#   Epoka 260 | Total Loss: 0.0364
#   Epoka 280 | Total Loss: 0.0325
#   Epoka 300 | Total Loss: 0.0305
#   Epoka 320 | Total Loss: 0.0274
#   Epoka 340 | Total Loss: 0.0263
#   Epoka 360 | Total Loss: 0.0254
#   Epoka 380 | Total Loss: 0.0241
#   Epoka 400 | Total Loss: 0.0266
#   Epoka 420 | Total Loss: 0.0217
#   Epoka 440 | Total Loss: 0.0211
#   Epoka 460 | Total Loss: 0.0205
#   Epoka 480 | Total Loss: 0.0189
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4829
#   MAE      : 0.3796
#   R²       : 0.6329
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.7175
#   MAE      : 0.5629
#   R²       : 0.6515
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# # Test2: Caco-2 (Wang) + Lipophilicity (Astra Zeneca) + Solubility (AqSolDB)

# %% [markdown]
# Sprawdzamy czy dołożenie kolejnego powiązanego zbioru poprawi wynik.

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang', 'Lipophilicity_AZ', 'Solubility_AqSolDB']
class_tasks = [] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca', 'AqSolDB']

# 1. Ładowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_lipo,  test_lipo  = load_split_pickle('Lipophilicity_AstraZeneca')
train_sol,   test_sol   = load_split_pickle('Solubility_AqSolDB')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_lipo, train_sol], reg_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2,  test_lipo,  test_sol],  reg_tasks, dataset_names)
loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 4.0301
#   Epoka  20 | Total Loss: 1.6682
#   Epoka  40 | Total Loss: 1.1637
#   Epoka  60 | Total Loss: 0.8885
#   Epoka  80 | Total Loss: 0.6831
#   Epoka 100 | Total Loss: 0.5206
#   Epoka 120 | Total Loss: 0.4014
#   Epoka 140 | Total Loss: 0.3180
#   Epoka 160 | Total Loss: 0.2605
#   Epoka 180 | Total Loss: 0.2270
#   Epoka 200 | Total Loss: 0.1933
#   Epoka 220 | Total Loss: 0.2180
#   Epoka 240 | Total Loss: 0.1520
#   Epoka 260 | Total Loss: 0.1429
#   Epoka 280 | Total Loss: 0.1250
#   Epoka 300 | Total Loss: 0.1214
#   Epoka 320 | Total Loss: 0.1081
#   Epoka 340 | Total Loss: 0.1030
#   Epoka 360 | Total Loss: 0.1034
#   Epoka 380 | Total Loss: 0.0919
#   Epoka 400 | Total Loss: 0.0849
#   Epoka 420 | Total Loss: 0.0844
#   Epoka 440 | Total Loss: 0.0890
#   Epoka 460 | Total Loss: 0.0786
#   Epoka 480 | Total Loss: 0.0742
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.4716
#   MAE      : 0.3711
#   R²       : 0.6499
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.7137
#   MAE      : 0.5569
#   R²       : 0.6553
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 1.1622
#   MAE      : 0.8545
#   R²       : 0.7511
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 1.3122
#   Epoka  20 | Total Loss: 0.5642
#   Epoka  40 | Total Loss: 0.3964
#   Epoka  60 | Total Loss: 0.3049
#   Epoka  80 | Total Loss: 0.2313
#   Epoka 100 | Total Loss: 0.1738
#   Epoka 120 | Total Loss: 0.1450
#   Epoka 140 | Total Loss: 0.1155
#   Epoka 160 | Total Loss: 0.0918
#   Epoka 180 | Total Loss: 0.0854
#   Epoka 200 | Total Loss: 0.0698
#   Epoka 220 | Total Loss: 0.0624
#   Epoka 240 | Total Loss: 0.0557
#   Epoka 260 | Total Loss: 0.0517
#   Epoka 280 | Total Loss: 0.0491
#   Epoka 300 | Total Loss: 0.0432
#   Epoka 320 | Total Loss: 0.0409
#   Epoka 340 | Total Loss: 0.0369
#   Epoka 360 | Total Loss: 0.0357
#   Epoka 380 | Total Loss: 0.0312
#   Epoka 400 | Total Loss: 0.0313
#   Epoka 420 | Total Loss: 0.0295
#   Epoka 440 | Total Loss: 0.0286
#   Epoka 460 | Total Loss: 0.0299
#   Epoka 480 | Total Loss: 0.0267
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4720
#   MAE      : 0.3798
#   R²       : 0.6494
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.7098
#   MAE      : 0.5463
#   R²       : 0.6590
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 1.1510
#   MAE      : 0.8466
#   R²       : 0.7559
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 2.2242
#   Epoka  20 | Total Loss: 0.8867
#   Epoka  40 | Total Loss: 0.6271
#   Epoka  60 | Total Loss: 0.4907
#   Epoka  80 | Total Loss: 0.3812
#   Epoka 100 | Total Loss: 0.3052
#   Epoka 120 | Total Loss: 0.2512
#   Epoka 140 | Total Loss: 0.2021
#   Epoka 160 | Total Loss: 0.1730
#   Epoka 180 | Total Loss: 0.1437
#   Epoka 200 | Total Loss: 0.1216
#   Epoka 220 | Total Loss: 0.1069
#   Epoka 240 | Total Loss: 0.0924
#   Epoka 260 | Total Loss: 0.0815
#   Epoka 280 | Total Loss: 0.0781
#   Epoka 300 | Total Loss: 0.0690
#   Epoka 320 | Total Loss: 0.0651
#   Epoka 340 | Total Loss: 0.0659
#   Epoka 360 | Total Loss: 0.0549
#   Epoka 380 | Total Loss: 0.0531
#   Epoka 400 | Total Loss: 0.0486
#   Epoka 420 | Total Loss: 0.0520
#   Epoka 440 | Total Loss: 0.0479
#   Epoka 460 | Total Loss: 0.0428
#   Epoka 480 | Total Loss: 0.0399
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4983
#   MAE      : 0.3923
#   R²       : 0.6091
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.7355
#   MAE      : 0.5642
#   R²       : 0.6338
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 1.1820
#   MAE      : 0.8597
#   R²       : 0.7426
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# # Test3:  Caco-2 (Wang) + Lipophilicity (Astra Zeneca) + Solubility (AqSolDB) + HIA (Hou)

# %% [markdown]
# Sprawdzamy czy dołożenie kolejnego powiązanego zbioru poprawi wynik. Czy w jakimś momencie wyniki przestają się poprawiać?

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang', 'Lipophilicity_AZ', 'Solubility_AqSolDB']
class_tasks = ['HIA_Hou'] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca', 'AqSolDB', 'HIA_Hou']

# 1. Ładowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_lipo,  test_lipo  = load_split_pickle('Lipophilicity_AstraZeneca')
train_sol,   test_sol   = load_split_pickle('Solubility_AqSolDB')
train_hia,   test_hia   = load_split_pickle('HIA_Hou')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_lipo, train_sol, train_hia], reg_tasks + class_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2,  test_lipo,  test_sol,  test_hia],  reg_tasks + class_tasks, dataset_names)
loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 4.6001
#   Epoka  20 | Total Loss: 1.9795
#   Epoka  40 | Total Loss: 1.3766
#   Epoka  60 | Total Loss: 0.9866
#   Epoka  80 | Total Loss: 0.7023
#   Epoka 100 | Total Loss: 0.5177
#   Epoka 120 | Total Loss: 0.4286
#   Epoka 140 | Total Loss: 0.3428
#   Epoka 160 | Total Loss: 0.2810
#   Epoka 180 | Total Loss: 0.2353
#   Epoka 200 | Total Loss: 0.2094
#   Epoka 220 | Total Loss: 0.1805
#   Epoka 240 | Total Loss: 0.1644
#   Epoka 260 | Total Loss: 0.1598
#   Epoka 280 | Total Loss: 0.1359
#   Epoka 300 | Total Loss: 0.1304
#   Epoka 320 | Total Loss: 0.1204
#   Epoka 340 | Total Loss: 0.1147
#   Epoka 360 | Total Loss: 0.1040
#   Epoka 380 | Total Loss: 0.0961
#   Epoka 400 | Total Loss: 0.0934
#   Epoka 420 | Total Loss: 0.0902
#   Epoka 440 | Total Loss: 0.0835
#   Epoka 460 | Total Loss: 0.0792
#   Epoka 480 | Total Loss: 0.0777
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.5052
#   MAE      : 0.3936
#   R²       : 0.5982
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.7081
#   MAE      : 0.5480
#   R²       : 0.6606
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 1.1235
#   MAE      : 0.8110
#   R²       : 0.7674
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   Accuracy : 0.9741
#   F1       : 0.9846
#   AUROC    : 0.9957
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 1.1510
#   Epoka  20 | Total Loss: 0.5007
#   Epoka  40 | Total Loss: 0.3489
#   Epoka  60 | Total Loss: 0.2514
#   Epoka  80 | Total Loss: 0.1820
#   Epoka 100 | Total Loss: 0.1362
#   Epoka 120 | Total Loss: 0.1036
#   Epoka 140 | Total Loss: 0.0824
#   Epoka 160 | Total Loss: 0.0666
#   Epoka 180 | Total Loss: 0.0563
#   Epoka 200 | Total Loss: 0.0506
#   Epoka 220 | Total Loss: 0.0463
#   Epoka 240 | Total Loss: 0.0391
#   Epoka 260 | Total Loss: 0.0356
#   Epoka 280 | Total Loss: 0.0332
#   Epoka 300 | Total Loss: 0.0318
#   Epoka 320 | Total Loss: 0.0286
#   Epoka 340 | Total Loss: 0.0272
#   Epoka 360 | Total Loss: 0.0257
#   Epoka 380 | Total Loss: 0.0248
#   Epoka 400 | Total Loss: 0.0252
#   Epoka 420 | Total Loss: 0.0229
#   Epoka 440 | Total Loss: 0.0226
#   Epoka 460 | Total Loss: 0.0215
#   Epoka 480 | Total Loss: 0.0227
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4974
#   MAE      : 0.3890
#   R²       : 0.6106
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.7313
#   MAE      : 0.5634
#   R²       : 0.6381
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 1.1470
#   MAE      : 0.8417
#   R²       : 0.7576
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   Accuracy : 0.9655
#   F1       : 0.9794
#   AUROC    : 0.9946
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 2.6219
#   Epoka  20 | Total Loss: 0.9927
#   Epoka  40 | Total Loss: 0.6976
#   Epoka  60 | Total Loss: 0.4682
#   Epoka  80 | Total Loss: 0.3342
#   Epoka 100 | Total Loss: 0.2471
#   Epoka 120 | Total Loss: 0.1867
#   Epoka 140 | Total Loss: 0.1477
#   Epoka 160 | Total Loss: 0.1167
#   Epoka 180 | Total Loss: 0.1027
#   Epoka 200 | Total Loss: 0.0906
#   Epoka 220 | Total Loss: 0.0814
#   Epoka 240 | Total Loss: 0.0722
#   Epoka 260 | Total Loss: 0.0664
#   Epoka 280 | Total Loss: 0.0614
#   Epoka 300 | Total Loss: 0.0575
#   Epoka 320 | Total Loss: 0.0553
#   Epoka 340 | Total Loss: 0.0495
#   Epoka 360 | Total Loss: 0.0539
#   Epoka 380 | Total Loss: 0.0493
#   Epoka 400 | Total Loss: 0.0426
#   Epoka 420 | Total Loss: 0.0421
#   Epoka 440 | Total Loss: 0.0400
#   Epoka 460 | Total Loss: 0.0386
#   Epoka 480 | Total Loss: 0.0376
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4826
#   MAE      : 0.3770
#   R²       : 0.6334
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.7165
#   MAE      : 0.5553
#   R²       : 0.6525
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 1.1369
#   MAE      : 0.8359
#   R²       : 0.7618
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   Accuracy : 0.9569
#   F1       : 0.9741
#   AUROC    : 0.9946
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# # Test4: Caco-2 (Wang) + HIA (Hou)

# %% [markdown]
# Sprawdzamy czy mały zbiór HIA pomoże CaCo-2 mniej niż większe zbiory z poprzednich testów. Jednocześnie sparwdzamy STL vs MTL.

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang']
class_tasks = ['HIA_Hou'] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'HIA_Hou']

# 1. Ładowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_hia,   test_hia   = load_split_pickle('HIA_Hou')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_hia], reg_tasks + class_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2,  test_hia],  reg_tasks + class_tasks, dataset_names)
loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 1.8607
#   Epoka  20 | Total Loss: 0.8043
#   Epoka  40 | Total Loss: 0.5403
#   Epoka  60 | Total Loss: 0.3706
#   Epoka  80 | Total Loss: 0.2166
#   Epoka 100 | Total Loss: 0.1272
#   Epoka 120 | Total Loss: 0.0759
#   Epoka 140 | Total Loss: 0.0511
#   Epoka 160 | Total Loss: 0.0414
#   Epoka 180 | Total Loss: 0.0340
#   Epoka 200 | Total Loss: 0.0281
#   Epoka 220 | Total Loss: 0.0244
#   Epoka 240 | Total Loss: 0.0233
#   Epoka 260 | Total Loss: 0.0201
#   Epoka 280 | Total Loss: 0.0188
#   Epoka 300 | Total Loss: 0.0203
#   Epoka 320 | Total Loss: 0.0175
#   Epoka 340 | Total Loss: 0.0158
#   Epoka 360 | Total Loss: 0.0158
#   Epoka 380 | Total Loss: 0.0148
#   Epoka 400 | Total Loss: 0.0131
#   Epoka 420 | Total Loss: 0.0131
#   Epoka 440 | Total Loss: 0.0126
#   Epoka 460 | Total Loss: 0.0130
#   Epoka 480 | Total Loss: 0.0131
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.4851
#   MAE      : 0.3789
#   R²       : 0.6296
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   Accuracy : 0.9569
#   F1       : 0.9741
#   AUROC    : 0.9946
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 0.9872
#   Epoka  20 | Total Loss: 0.3530
#   Epoka  40 | Total Loss: 0.1960
#   Epoka  60 | Total Loss: 0.0947
#   Epoka  80 | Total Loss: 0.0378
#   Epoka 100 | Total Loss: 0.0242
#   Epoka 120 | Total Loss: 0.0163
#   Epoka 140 | Total Loss: 0.0142
#   Epoka 160 | Total Loss: 0.0119
#   Epoka 180 | Total Loss: 0.0113
#   Epoka 200 | Total Loss: 0.0088
#   Epoka 220 | Total Loss: 0.0081
#   Epoka 240 | Total Loss: 0.0085
#   Epoka 260 | Total Loss: 0.0076
#   Epoka 280 | Total Loss: 0.0072
#   Epoka 300 | Total Loss: 0.0069
#   Epoka 320 | Total Loss: 0.0058
#   Epoka 340 | Total Loss: 0.0067
#   Epoka 360 | Total Loss: 0.0056
#   Epoka 380 | Total Loss: 0.0050
#   Epoka 400 | Total Loss: 0.0054
#   Epoka 420 | Total Loss: 0.0054
#   Epoka 440 | Total Loss: 0.0052
#   Epoka 460 | Total Loss: 0.0045
#   Epoka 480 | Total Loss: 0.0051
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4690
#   MAE      : 0.3707
#   R²       : 0.6538
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   Accuracy : 0.9569
#   F1       : 0.9741
#   AUROC    : 0.9940
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 1.4157
#   Epoka  20 | Total Loss: 0.4267
#   Epoka  40 | Total Loss: 0.2447
#   Epoka  60 | Total Loss: 0.1021
#   Epoka  80 | Total Loss: 0.0451
#   Epoka 100 | Total Loss: 0.0234
#   Epoka 120 | Total Loss: 0.0184
#   Epoka 140 | Total Loss: 0.0131
#   Epoka 160 | Total Loss: 0.0111
#   Epoka 180 | Total Loss: 0.0104
#   Epoka 200 | Total Loss: 0.0102
#   Epoka 220 | Total Loss: 0.0097
#   Epoka 240 | Total Loss: 0.0080
#   Epoka 260 | Total Loss: 0.0084
#   Epoka 280 | Total Loss: 0.0069
#   Epoka 300 | Total Loss: 0.0071
#   Epoka 320 | Total Loss: 0.0067
#   Epoka 340 | Total Loss: 0.0070
#   Epoka 360 | Total Loss: 0.0058
#   Epoka 380 | Total Loss: 0.0055
#   Epoka 400 | Total Loss: 0.0060
#   Epoka 420 | Total Loss: 0.0056
#   Epoka 440 | Total Loss: 0.0054
#   Epoka 460 | Total Loss: 0.0052
#   Epoka 480 | Total Loss: 0.0048
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4802
#   MAE      : 0.3721
#   R²       : 0.6371
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   Accuracy : 0.9569
#   F1       : 0.9741
#   AUROC    : 0.9946
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# # Test5: Lipophilicity (Astra Zeneca) + Solubility (AqSolDB)

# %% [markdown]
# Sprawdzamy czy duży zbiór Solubility pomoże innemu dużemu zbiorowi mniej niż małemu CaCo-2. Jednocześnie sprawdzamy STL vs MTL.

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Lipophilicity_AZ', 'Solubility_AqSolDB']
class_tasks = [] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Lipophilicity_AstraZeneca', 'AqSolDB']

# 1. Ładowanie danych
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_sol,  test_sol  = load_split_pickle('Solubility_AqSolDB')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_lipo, train_sol], reg_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_lipo,  test_sol],  reg_tasks, dataset_names)
loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 4.9315
#   Epoka  20 | Total Loss: 1.3771
#   Epoka  40 | Total Loss: 0.9698
#   Epoka  60 | Total Loss: 0.7874
#   Epoka  80 | Total Loss: 0.6301
#   Epoka 100 | Total Loss: 0.5054
#   Epoka 120 | Total Loss: 0.4157
#   Epoka 140 | Total Loss: 0.3368
#   Epoka 160 | Total Loss: 0.2882
#   Epoka 180 | Total Loss: 0.2425
#   Epoka 200 | Total Loss: 0.2174
#   Epoka 220 | Total Loss: 0.1854
#   Epoka 240 | Total Loss: 0.1689
#   Epoka 260 | Total Loss: 0.1436
#   Epoka 280 | Total Loss: 0.1277
#   Epoka 300 | Total Loss: 0.1230
#   Epoka 320 | Total Loss: 0.1059
#   Epoka 340 | Total Loss: 0.1022
#   Epoka 360 | Total Loss: 0.0876
#   Epoka 380 | Total Loss: 0.0869
#   Epoka 400 | Total Loss: 0.0818
#   Epoka 420 | Total Loss: 0.0787
#   Epoka 440 | Total Loss: 0.0726
#   Epoka 460 | Total Loss: 0.0706
#   Epoka 480 | Total Loss: 0.0663
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.7210
#   MAE      : 0.5535
#   R²       : 0.6482
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 1.2043
#   MAE      : 0.8755
#   R²       : 0.7327
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 1.3515
#   Epoka  20 | Total Loss: 0.6814
#   Epoka  40 | Total Loss: 0.4996
#   Epoka  60 | Total Loss: 0.4153
#   Epoka  80 | Total Loss: 0.3426
#   Epoka 100 | Total Loss: 0.2802
#   Epoka 120 | Total Loss: 0.2290
#   Epoka 140 | Total Loss: 0.1867
#   Epoka 160 | Total Loss: 0.1596
#   Epoka 180 | Total Loss: 0.1302
#   Epoka 200 | Total Loss: 0.1180
#   Epoka 220 | Total Loss: 0.1096
#   Epoka 240 | Total Loss: 0.0901
#   Epoka 260 | Total Loss: 0.0782
#   Epoka 280 | Total Loss: 0.0714
#   Epoka 300 | Total Loss: 0.0710
#   Epoka 320 | Total Loss: 0.0617
#   Epoka 340 | Total Loss: 0.0581
#   Epoka 360 | Total Loss: 0.0492
#   Epoka 380 | Total Loss: 0.0468
#   Epoka 400 | Total Loss: 0.0497
#   Epoka 420 | Total Loss: 0.0439
#   Epoka 440 | Total Loss: 0.0429
#   Epoka 460 | Total Loss: 0.0455
#   Epoka 480 | Total Loss: 0.0359
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.7195
#   MAE      : 0.5538
#   R²       : 0.6496
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 1.1454
#   MAE      : 0.8368
#   R²       : 0.7583
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 1.1737
#   Epoka  20 | Total Loss: 0.5947
#   Epoka  40 | Total Loss: 0.4802
#   Epoka  60 | Total Loss: 0.3924
#   Epoka  80 | Total Loss: 0.3188
#   Epoka 100 | Total Loss: 0.2562
#   Epoka 120 | Total Loss: 0.2118
#   Epoka 140 | Total Loss: 0.1857
#   Epoka 160 | Total Loss: 0.1540
#   Epoka 180 | Total Loss: 0.1278
#   Epoka 200 | Total Loss: 0.1209
#   Epoka 220 | Total Loss: 0.0993
#   Epoka 240 | Total Loss: 0.0880
#   Epoka 260 | Total Loss: 0.0816
#   Epoka 280 | Total Loss: 0.0704
#   Epoka 300 | Total Loss: 0.0633
#   Epoka 320 | Total Loss: 0.0588
#   Epoka 340 | Total Loss: 0.0520
#   Epoka 360 | Total Loss: 0.0489
#   Epoka 380 | Total Loss: 0.0468
#   Epoka 400 | Total Loss: 0.0442
#   Epoka 420 | Total Loss: 0.0411
#   Epoka 440 | Total Loss: 0.0413
#   Epoka 460 | Total Loss: 0.0359
#   Epoka 480 | Total Loss: 0.0454
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.7316
#   MAE      : 0.5551
#   R²       : 0.6377
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 1.1382
#   MAE      : 0.8302
#   R²       : 0.7613
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# # Test6: Caco-2 (Wang) + AMES Mutagenicity

# %% [markdown]
# Sprawdzamy czy zbiór niepowiązany pomoże zbiorowi CaCo-2.

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang']
class_tasks = ['AMES'] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'AMES']

# 1. Ładowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_ames,  test_ames  = load_split_pickle('AMES')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_ames], reg_tasks + class_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2,  test_ames],  reg_tasks + class_tasks, dataset_names)
loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 1.7746
#   Epoka  20 | Total Loss: 0.8706
#   Epoka  40 | Total Loss: 0.7112
#   Epoka  60 | Total Loss: 0.5535
#   Epoka  80 | Total Loss: 0.4232
#   Epoka 100 | Total Loss: 0.3027
#   Epoka 120 | Total Loss: 0.1975
#   Epoka 140 | Total Loss: 0.1124
#   Epoka 160 | Total Loss: 0.0698
#   Epoka 180 | Total Loss: 0.0493
#   Epoka 200 | Total Loss: 0.0366
#   Epoka 220 | Total Loss: 0.0304
#   Epoka 240 | Total Loss: 0.0292
#   Epoka 260 | Total Loss: 0.0236
#   Epoka 280 | Total Loss: 0.0242
#   Epoka 300 | Total Loss: 0.0232
#   Epoka 320 | Total Loss: 0.0208
#   Epoka 340 | Total Loss: 0.0172
#   Epoka 360 | Total Loss: 0.0169
#   Epoka 380 | Total Loss: 0.0140
#   Epoka 400 | Total Loss: 0.0160
#   Epoka 420 | Total Loss: 0.0139
#   Epoka 440 | Total Loss: 0.0119
#   Epoka 460 | Total Loss: 0.0152
#   Epoka 480 | Total Loss: 0.0128
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.4874
#   MAE      : 0.3832
#   R²       : 0.6261
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   Accuracy : 0.7950
#   F1       : 0.8087
#   AUROC    : 0.8755
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 0.9026
#   Epoka  20 | Total Loss: 0.4899
#   Epoka  40 | Total Loss: 0.4035
#   Epoka  60 | Total Loss: 0.3303
#   Epoka  80 | Total Loss: 0.2707
#   Epoka 100 | Total Loss: 0.2208
#   Epoka 120 | Total Loss: 0.1720
#   Epoka 140 | Total Loss: 0.1272
#   Epoka 160 | Total Loss: 0.0845
#   Epoka 180 | Total Loss: 0.0510
#   Epoka 200 | Total Loss: 0.0341
#   Epoka 220 | Total Loss: 0.0252
#   Epoka 240 | Total Loss: 0.0220
#   Epoka 260 | Total Loss: 0.0162
#   Epoka 280 | Total Loss: 0.0136
#   Epoka 300 | Total Loss: 0.0125
#   Epoka 320 | Total Loss: 0.0127
#   Epoka 340 | Total Loss: 0.0120
#   Epoka 360 | Total Loss: 0.0097
#   Epoka 380 | Total Loss: 0.0114
#   Epoka 400 | Total Loss: 0.0091
#   Epoka 420 | Total Loss: 0.0090
#   Epoka 440 | Total Loss: 0.0082
#   Epoka 460 | Total Loss: 0.0082
#   Epoka 480 | Total Loss: 0.0074
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4848
#   MAE      : 0.3850
#   R²       : 0.6300
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   Accuracy : 0.7889
#   F1       : 0.8070
#   AUROC    : 0.8704
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 1.3353
#   Epoka  20 | Total Loss: 0.7521
#   Epoka  40 | Total Loss: 0.6367
#   Epoka  60 | Total Loss: 0.5256
#   Epoka  80 | Total Loss: 0.4043
#   Epoka 100 | Total Loss: 0.2719
#   Epoka 120 | Total Loss: 0.1907
#   Epoka 140 | Total Loss: 0.1060
#   Epoka 160 | Total Loss: 0.0716
#   Epoka 180 | Total Loss: 0.0437
#   Epoka 200 | Total Loss: 0.0304
#   Epoka 220 | Total Loss: 0.0242
#   Epoka 240 | Total Loss: 0.0213
#   Epoka 260 | Total Loss: 0.0224
#   Epoka 280 | Total Loss: 0.0179
#   Epoka 300 | Total Loss: 0.0147
#   Epoka 320 | Total Loss: 0.0134
#   Epoka 340 | Total Loss: 0.0120
#   Epoka 360 | Total Loss: 0.0118
#   Epoka 380 | Total Loss: 0.0110
#   Epoka 400 | Total Loss: 0.0093
#   Epoka 420 | Total Loss: 0.0105
#   Epoka 440 | Total Loss: 0.0103
#   Epoka 460 | Total Loss: 0.0087
#   Epoka 480 | Total Loss: 0.0078
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4807
#   MAE      : 0.3735
#   R²       : 0.6362
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   Accuracy : 0.7944
#   F1       : 0.8132
#   AUROC    : 0.8701
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# # Test7: Caco-2 (Wang)+ Lipophilicity (Astra Zeneca)  + AMES Mutagenicity

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang', 'Lipophilicity_AZ']
class_tasks = ['AMES'] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca', 'AMES']

# 1. Ladowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_ames, test_ames = load_split_pickle('AMES')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_lipo, train_ames], reg_tasks + class_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2, test_lipo, test_ames], reg_tasks + class_tasks, dataset_names)
loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 2.9593
#   Epoka  20 | Total Loss: 1.7436
#   Epoka  40 | Total Loss: 1.2946
#   Epoka  60 | Total Loss: 0.9957
#   Epoka  80 | Total Loss: 0.7563
#   Epoka 100 | Total Loss: 0.5771
#   Epoka 120 | Total Loss: 0.4087
#   Epoka 140 | Total Loss: 0.3237
#   Epoka 160 | Total Loss: 0.2160
#   Epoka 180 | Total Loss: 0.1606
#   Epoka 200 | Total Loss: 0.1275
#   Epoka 220 | Total Loss: 0.1136
#   Epoka 240 | Total Loss: 0.1137
#   Epoka 260 | Total Loss: 0.0824
#   Epoka 280 | Total Loss: 0.0706
#   Epoka 300 | Total Loss: 0.0675
#   Epoka 320 | Total Loss: 0.0596
#   Epoka 340 | Total Loss: 0.0630
#   Epoka 360 | Total Loss: 0.0542
#   Epoka 380 | Total Loss: 0.0538
#   Epoka 400 | Total Loss: 0.0552
#   Epoka 420 | Total Loss: 0.0544
#   Epoka 440 | Total Loss: 0.0467
#   Epoka 460 | Total Loss: 0.0480
#   Epoka 480 | Total Loss: 0.0410
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.4952
#   MAE      : 0.3932
#   R²       : 0.6140
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.7244
#   MAE      : 0.5610
#   R²       : 0.6449
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   Accuracy : 0.7889
#   F1       : 0.8075
#   AUROC    : 0.8619
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 1.0101
#   Epoka  20 | Total Loss: 0.6439
#   Epoka  40 | Total Loss: 0.4918
#   Epoka  60 | Total Loss: 0.3983
#   Epoka  80 | Total Loss: 0.3172
#   Epoka 100 | Total Loss: 0.2615
#   Epoka 120 | Total Loss: 0.2139
#   Epoka 140 | Total Loss: 0.1792
#   Epoka 160 | Total Loss: 0.1361
#   Epoka 180 | Total Loss: 0.1069
#   Epoka 200 | Total Loss: 0.0832
#   Epoka 220 | Total Loss: 0.0714
#   Epoka 240 | Total Loss: 0.0642
#   Epoka 260 | Total Loss: 0.0453
#   Epoka 280 | Total Loss: 0.0366
#   Epoka 300 | Total Loss: 0.0352
#   Epoka 320 | Total Loss: 0.0314
#   Epoka 340 | Total Loss: 0.0303
#   Epoka 360 | Total Loss: 0.0244
#   Epoka 380 | Total Loss: 0.0246
#   Epoka 400 | Total Loss: 0.0217
#   Epoka 420 | Total Loss: 0.0197
#   Epoka 440 | Total Loss: 0.0182
#   Epoka 460 | Total Loss: 0.0194
#   Epoka 480 | Total Loss: 0.0170
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4948
#   MAE      : 0.3819
#   R²       : 0.6145
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.7239
#   MAE      : 0.5579
#   R²       : 0.6453
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   Accuracy : 0.7854
#   F1       : 0.8028
#   AUROC    : 0.8610
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 1.9766
#   Epoka  20 | Total Loss: 1.2113
#   Epoka  40 | Total Loss: 0.9530
#   Epoka  60 | Total Loss: 0.7996
#   Epoka  80 | Total Loss: 0.6665
#   Epoka 100 | Total Loss: 0.5388
#   Epoka 120 | Total Loss: 0.4008
#   Epoka 140 | Total Loss: 0.3008
#   Epoka 160 | Total Loss: 0.1925
#   Epoka 180 | Total Loss: 0.1303
#   Epoka 200 | Total Loss: 0.1047
#   Epoka 220 | Total Loss: 0.0840
#   Epoka 240 | Total Loss: 0.0762
#   Epoka 260 | Total Loss: 0.0615
#   Epoka 280 | Total Loss: 0.0503
#   Epoka 300 | Total Loss: 0.0454
#   Epoka 320 | Total Loss: 0.0452
#   Epoka 340 | Total Loss: 0.0378
#   Epoka 360 | Total Loss: 0.0339
#   Epoka 380 | Total Loss: 0.0335
#   Epoka 400 | Total Loss: 0.0449
#   Epoka 420 | Total Loss: 0.0292
#   Epoka 440 | Total Loss: 0.0282
#   Epoka 460 | Total Loss: 0.0268
#   Epoka 480 | Total Loss: 0.0260
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4742
#   MAE      : 0.3717
#   R²       : 0.6460
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.7341
#   MAE      : 0.5684
#   R²       : 0.6352
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   Accuracy : 0.8047
#   F1       : 0.8238
#   AUROC    : 0.8771
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt

# %% [markdown]
# #Test 8: Caco-2 (Wang) + Lipophilicity (Astra Zeneca) + Solubility (AqSolDB) + HIA (Hou)  + AMES

# %%
# --- KONFIGURACJA I URUCHOMIENIE ---

reg_tasks = ['Caco2_Wang', 'Lipophilicity_AZ', 'Solubility_AqSolDB']
class_tasks = ['HIA_Hou', 'AMES'] # Dodaj tu zadania klasyfikacyjne
filepath = "/content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt"

dataset_names = ['Caco2_Wang', 'Lipophilicity_AstraZeneca', 'AqSolDB', 'HIA_Hou', 'AMES']

# 1. Ladowanie danych
train_caco2, test_caco2 = load_split_pickle('Caco2_Wang')
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_sol, test_sol = load_split_pickle('Solubility_AqSolDB')
train_hia, test_hia = load_split_pickle('HIA_Hou')
train_ames, test_ames = load_split_pickle('AMES')

# 2. Przygotowanie danych MTL
X_train_mtl, y_train_dict = prepare_mtl_data_embeddings([train_caco2, train_lipo, train_sol, train_hia, train_ames], reg_tasks + class_tasks, dataset_names)
X_test_mtl,  y_test_dict  = prepare_mtl_data_embeddings([test_caco2, test_lipo, test_sol, test_hia, test_ames], reg_tasks + class_tasks, dataset_names)

loss_schemes = [
    (train_MTL_hybrid_wl_sum, "Weighted Loss Sum"),
    (train_MTL_hybrid_uniform_average, "Uniform Average"),
    (train_MTL_hybrid_uncertainty_weighting, "Uncertainty Weighting")
]

# Loop through each loss weighting scheme
for train_func, scheme_name in loss_schemes:


    # 3. Uruchomienie treningu
    results = train_func(
        X_train_mtl,
        X_test_mtl,
        y_train_dict,
        y_test_dict,
        reg_tasks,
        class_tasks=class_tasks
    )

    # 4. RAPORTOWANIE I ZAPISYWANIE WYNIKOW

    print("\n" + "="*40)
    print(f"       PODSUMOWANIE MODELU MTL - {scheme_name}")
    print("="*40)

    endpoint_group = str(reg_tasks + class_tasks)

    # Przetwarzanie zadan regresyjnych
    for task_name, task_metrics in results['reg_tasks'].items():
        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Regresja): {task_name}")
        print_metrics(formatted_wrapper, task='regression', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='regression', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

    # Przetwarzanie zadan klasyfikacyjnych (jesli istnieja)
    for task_name, task_metrics in results['class_tasks'].items():

        # if 'f1' not in task_metrics:
        #     task_metrics['f1'] = 0.0  # Wypelnienie, jesli funkcja wymaga f1

        formatted_wrapper = {"test_metrics": task_metrics}

        print(f"\nWyniki dla zadania (Klasyfikacja): {task_name}")
        print_metrics(formatted_wrapper, task='classification', weight_loss_func_name=scheme_name)
        save_metrics(formatted_wrapper, task_name, filepath, task='classification', weight_loss_func_name=scheme_name, endpoint_group_name=endpoint_group)

print(f"\nWszystkie wyniki zostaly zapisane w: {filepath}")
# Out:
# --- START TRENINGU (Multi-Task) ---
#   Epoka   0 | Total Loss: 4.7760
#   Epoka  20 | Total Loss: 2.4280
#   Epoka  40 | Total Loss: 1.8485
#   Epoka  60 | Total Loss: 1.4229
#   Epoka  80 | Total Loss: 1.1081
#   Epoka 100 | Total Loss: 0.8887
#   Epoka 120 | Total Loss: 0.7375
#   Epoka 140 | Total Loss: 0.5970
#   Epoka 160 | Total Loss: 0.4903
#   Epoka 180 | Total Loss: 0.3877
#   Epoka 200 | Total Loss: 0.3409
#   Epoka 220 | Total Loss: 0.2661
#   Epoka 240 | Total Loss: 0.2268
#   Epoka 260 | Total Loss: 0.2022
#   Epoka 280 | Total Loss: 0.1701
#   Epoka 300 | Total Loss: 0.1568
#   Epoka 320 | Total Loss: 0.1579
#   Epoka 340 | Total Loss: 0.1445
#   Epoka 360 | Total Loss: 0.1290
#   Epoka 380 | Total Loss: 0.1234
#   Epoka 400 | Total Loss: 0.1258
#   Epoka 420 | Total Loss: 0.1138
#   Epoka 440 | Total Loss: 0.1028
#   Epoka 460 | Total Loss: 0.1038
#   Epoka 480 | Total Loss: 0.1127
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Weighted Loss Sum
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.4932
#   MAE      : 0.3877
#   R²       : 0.6171
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 0.7190
#   MAE      : 0.5487
#   R²       : 0.6501
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   RMSE     : 1.1245
#   MAE      : 0.8174
#   R²       : 0.7670
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   Accuracy : 0.9569
#   F1       : 0.9744
#   AUROC    : 0.9929
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Weighted Loss Sum
# ========================================
#   Accuracy : 0.7889
#   F1       : 0.8080
#   AUROC    : 0.8637
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uniform Average) ---
#   Epoka   0 | Total Loss: 1.0369
#   Epoka  20 | Total Loss: 0.5300
#   Epoka  40 | Total Loss: 0.4015
#   Epoka  60 | Total Loss: 0.3171
#   Epoka  80 | Total Loss: 0.2477
#   Epoka 100 | Total Loss: 0.2010
#   Epoka 120 | Total Loss: 0.1697
#   Epoka 140 | Total Loss: 0.1383
#   Epoka 160 | Total Loss: 0.1131
#   Epoka 180 | Total Loss: 0.0908
#   Epoka 200 | Total Loss: 0.0718
#   Epoka 220 | Total Loss: 0.0610
#   Epoka 240 | Total Loss: 0.0514
#   Epoka 260 | Total Loss: 0.0451
#   Epoka 280 | Total Loss: 0.0392
#   Epoka 300 | Total Loss: 0.0352
#   Epoka 320 | Total Loss: 0.0331
#   Epoka 340 | Total Loss: 0.0298
#   Epoka 360 | Total Loss: 0.0307
#   Epoka 380 | Total Loss: 0.0261
#   Epoka 400 | Total Loss: 0.0255
#   Epoka 420 | Total Loss: 0.0261
#   Epoka 440 | Total Loss: 0.0223
#   Epoka 460 | Total Loss: 0.0224
#   Epoka 480 | Total Loss: 0.0199
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uniform Average
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.4871
#   MAE      : 0.3800
#   R²       : 0.6265
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 0.7197
#   MAE      : 0.5540
#   R²       : 0.6494
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   RMSE     : 1.1549
#   MAE      : 0.8426
#   R²       : 0.7542
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   Accuracy : 0.9655
#   F1       : 0.9796
#   AUROC    : 0.9935
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Uniform Average
# ========================================
#   Accuracy : 0.7923
#   F1       : 0.8124
#   AUROC    : 0.8722
# ========================================
#
#
# --- START TRENINGU (Multi-Task - Uncertainty Weighting) ---
#   Epoka   0 | Total Loss: 3.3930
#   Epoka  20 | Total Loss: 1.5327
#   Epoka  40 | Total Loss: 1.1591
#   Epoka  60 | Total Loss: 0.8476
#   Epoka  80 | Total Loss: 0.6589
#   Epoka 100 | Total Loss: 0.5241
#   Epoka 120 | Total Loss: 0.4006
#   Epoka 140 | Total Loss: 0.3110
#   Epoka 160 | Total Loss: 0.2296
#   Epoka 180 | Total Loss: 0.1855
#   Epoka 200 | Total Loss: 0.1498
#   Epoka 220 | Total Loss: 0.1249
#   Epoka 240 | Total Loss: 0.1069
#   Epoka 260 | Total Loss: 0.0979
#   Epoka 280 | Total Loss: 0.0940
#   Epoka 300 | Total Loss: 0.0852
#   Epoka 320 | Total Loss: 0.0789
#   Epoka 340 | Total Loss: 0.0873
#   Epoka 360 | Total Loss: 0.0673
#   Epoka 380 | Total Loss: 0.0607
#   Epoka 400 | Total Loss: 0.0585
#   Epoka 420 | Total Loss: 0.0567
#   Epoka 440 | Total Loss: 0.0555
#   Epoka 460 | Total Loss: 0.0591
#   Epoka 480 | Total Loss: 0.0487
#
# --- EWALUACJA ---
#
# ========================================
#        PODSUMOWANIE MODELU MTL - Uncertainty Weighting
# ========================================
#
# Wyniki dla zadania (Regresja): Caco2_Wang
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.4939
#   MAE      : 0.3885
#   R²       : 0.6159
# ========================================
#
#
# Wyniki dla zadania (Regresja): Lipophilicity_AZ
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 0.7143
#   MAE      : 0.5515
#   R²       : 0.6546
# ========================================
#
#
# Wyniki dla zadania (Regresja): Solubility_AqSolDB
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   RMSE     : 1.1211
#   MAE      : 0.8162
#   R²       : 0.7684
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): HIA_Hou
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   Accuracy : 0.9741
#   F1       : 0.9845
#   AUROC    : 0.9908
# ========================================
#
#
# Wyniki dla zadania (Klasyfikacja): AMES
#
# ========================================
#   Loss Weighting: Uncertainty Weighting
# ========================================
#   Accuracy : 0.8040
#   F1       : 0.8167
#   AUROC    : 0.8760
# ========================================
#
#
# Wszystkie wyniki zostaly zapisane w: /content/drive/MyDrive/MLDD - ADMET/mtl_results_absorpcja_embeddings_500epochs.txt
