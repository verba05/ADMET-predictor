# %% [markdown]
# ### **Random forest MTL na deskryptorach - zestaw 1 - Absorpcja**

# %% [markdown]
# Wykorzystana reprezentacja: **ECFP4**
#
# Lista endpointów:
#
#
# 1. Caco-2 (Wang)
# 2. Lipophilicity (AstraZeneca)
# 3. Solubility (AqSolDB)
# 4. HIA (Hou)
# 5. AMES Mutagenicity

# %% [markdown]
# Wyniki dla STL:

# %%
# !pip install rdkit
# !pip install pandas numpy scikit-learn -U
# !pip install pytdc --no-dependencies
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: rdkit in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (2023.9.6)
# Requirement already satisfied: pandas in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (3.0.3)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1cc3620>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pandas/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1c9f8f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pandas/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1c9e1e0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pandas/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1c9dac0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pandas/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1cd4440>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/pandas/
# Requirement already satisfied: numpy in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (2.4.6)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b33230>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/numpy/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b33020>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/numpy/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b33470>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/numpy/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b33680>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/numpy/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b33a10>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/numpy/
# Requirement already satisfied: scikit-learn in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (1.8.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b4c2f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/scikit-learn/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b4c200>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/scikit-learn/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b4c3e0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/scikit-learn/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b4c620>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/scikit-learn/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fe8d1b4c860>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/scikit-learn/
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.3.0 in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data_folder = "/content/drive/MyDrive/data_splits"

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import pandas as pd
from tdc.single_pred import ADME
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, roc_auc_score, accuracy_score, f1_score
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 7, in <module>
#     from rdkit import Chem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/__init__.py", line 15, in <module>
#     from rdkit import DataStructs, RDConfig, rdBase
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/DataStructs/__init__.py", line 13, in <module>
#     from rdkit.DataStructs import cDataStructs
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 7, in <module>
#     from rdkit import Chem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/__init__.py", line 16, in <module>
#     from rdkit.Chem import rdchem
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 7, in <module>
#     from rdkit import Chem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/__init__.py", line 24, in <module>
#     from rdkit.Chem.rdmolops import *
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 7, in <module>
#     from rdkit import Chem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/Draw/__init__.py", line 20, in <module>
#     from rdkit.Chem import rdDepictor
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 7, in <module>
#     from rdkit import Chem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/__init__.py", line 23, in <module>
#     from rdkit.Chem.Draw import IPythonConsole
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/Draw/__init__.py", line 21, in <module>
#     from rdkit.Chem.Draw import rdMolDraw2D
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 8, in <module>
#     from rdkit.Chem import AllChem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/AllChem.py", line 22, in <module>
#     from rdkit.Chem.EnumerateStereoisomers import (EnumerateStereoisomers,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/EnumerateStereoisomers.py", line 4, in <module>
#     from rdkit.Chem.rdDistGeom import EmbedMolecule
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 8, in <module>
#     from rdkit.Chem import AllChem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/AllChem.py", line 27, in <module>
#     from rdkit.Chem.rdFingerprintGenerator import *
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 8, in <module>
#     from rdkit.Chem import AllChem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/AllChem.py", line 29, in <module>
#     from rdkit.Chem.rdMolAlign import *
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 8, in <module>
#     from rdkit.Chem import AllChem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/AllChem.py", line 32, in <module>
#     from rdkit.Chem.rdMolTransforms import *
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 8, in <module>
#     from rdkit.Chem import AllChem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/AllChem.py", line 35, in <module>
#     from rdkit.Chem.rdReducedGraphs import *
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell
#     result = self._run_cell(
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3224, in _run_cell
#     result = runner(coro)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3446, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3687, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3747, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_10525/3240753066.py", line 8, in <module>
#     from rdkit.Chem import AllChem
#   File "/home/ivanverba/miniconda3/envs/mldd26/lib/python3.12/site-packages/rdkit/Chem/AllChem.py", line 36, in <module>
#     from rdkit.Chem.rdShapeHelpers import *
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/mldd26/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:46, in __getattr__(attr_name)
#      41     # Also print the message (with traceback).  This is because old versions
#      42     # of NumPy unfortunately set up the import to replace (and hide) the
#      43     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      44     # seem to swallow it and we should be failing anyway...
#      45     sys.stderr.write(msg + tb_msg)
# ---> 46     raise ImportError(msg)
#      48 ret = getattr(_multiarray_umath, attr_name, None)
#      49 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
def load_embeddings(dataset_name, train_df, test_df):
    """Wczytuje CSV z embeddingami i dzieli na train/test po SMILES."""
    file_path = os.path.join(data_folder, f'{dataset_name}_MoLFormer_embeddings.csv')
    emb_df = pd.read_csv(file_path)

    train_smiles = set(train_df['Drug'].tolist())
    test_smiles  = set(test_df['Drug'].tolist())

    emb_train = emb_df[emb_df['Drug'].isin(train_smiles)]
    emb_test  = emb_df[emb_df['Drug'].isin(test_smiles)]

    feature_cols = [c for c in emb_df.columns if c.startswith('emb_')]

    X_train = emb_train[feature_cols].values
    y_train = emb_train['Y'].values
    X_test  = emb_test[feature_cols].values
    y_test  = emb_test['Y'].values

    # ZWRACAMY TEŻ EMB_TRAIN I EMB_TEST - dzięki temu zachowujemy kolumnę 'Drug' do MTL!
    return X_train, y_train, X_test, y_test, emb_train, emb_test

# %%
import pickle

def load_split_pickle(dataset_name):
    filepath = f"{data_folder}/{dataset_name}_split.pkl"

    with open(filepath, "rb") as f:
        split = pickle.load(f)

    return split["train"], split["test"]

# %%
def print_metrics(metrics, task='classification', weight_loss_func_name=None):
    print(f"\n{'='*40}")
    if weight_loss_func_name: # Check if func_name is provided and not None
        print(f"  Loss Weighting: {weight_loss_func_name}")
        print(f"{'='*40}")
    if task == 'classification':
        print(f"  Accuracy : {metrics['test_metrics']['accuracy']:.4f}")
        print(f"  F1       : {metrics['test_metrics']['f1']:.4f}")
        print(f"  AUROC    : {metrics['test_metrics']['auroc']:.4f}")
    else:
        print(f"  RMSE     : {metrics['test_metrics']['rmse']:.4f}")
        print(f"  MAE      : {metrics['test_metrics']['mae']:.4f}")
        print(f"  R²       : {metrics['test_metrics']['r2']:.4f}")
    print(f"{'='*40}\n")


def save_metrics(metrics, dataset_name, filepath, task='classification', weight_loss_func_name=None, endpoint_group_name=None):
    with open(filepath, 'a') as f:
        f.write(f"\n{'='*40}\n")
        f.write(f"Endpoint    : {dataset_name}\n")
        if endpoint_group_name:
            f.write(f"Tasks       : {endpoint_group_name}\n")
        if weight_loss_func_name:
            f.write(f"Loss Weighting: {weight_loss_func_name}\n")
        f.write(f"{'='*40}\n")
        if task == 'classification':
            f.write(f"  Accuracy : {metrics['test_metrics']['accuracy']:.4f}\n")
            f.write(f"  F1       : {metrics['test_metrics']['f1']:.4f}\n")
            f.write(f"  AUROC    : {metrics['test_metrics']['auroc']:.4f}\n")
        else:
            f.write(f"  RMSE     : {metrics['test_metrics']['rmse']:.4f}\n")
            f.write(f"  MAE      : {metrics['test_metrics']['mae']:.4f}\n")
            f.write(f"  R²       : {metrics['test_metrics']['r2']:.4f}\n")
        f.write(f"{'='*40}\n")

# %%
import numpy as np
import pandas as pd

def prepare_mtl_data_final(df_list, task_names, featurizer):
    # 1. Zebranie wszystkich unikalnych struktur
    all_drugs = set()
    for df in df_list:
        valid = df['Drug'].dropna().astype(str).unique()
        all_drugs.update(valid)

    # 2. Walidacja cząsteczek przez RDKit przed stworzeniem master_list
    # To zapobiega rozbieżnościom rozmiarów X i y
    safe_master_list = []
    for drug in sorted(list(all_drugs)):
        mol = Chem.MolFromSmiles(drug)
        if mol: safe_master_list.append(drug)

    drug_to_idx = {drug: i for i, drug in enumerate(safe_master_list)}
    n_samples = len(safe_master_list)

    # 3. Generowanie X (tylko dla poprawnych cząsteczek)
    df_temp = pd.DataFrame({'Drug': safe_master_list})
    X_features, _ = featurizer(df_temp)

    # Sprawdzenie czy X zawiera NaN (zabezpieczenie przed błędami featurizera)
    if np.isnan(X_features).any():
        X_features = np.nan_to_num(X_features)

    # 4. Mapowanie etykiet y (z zachowaniem NaN tylko w etykietach!)
    y_dict = {}
    for df, task in zip(df_list, task_names):
        y_vec = np.full((n_samples, 1), np.nan, dtype=np.float32)
        # Tworzymy mapę {Drug: Wynik}
        mapping = dict(zip(df['Drug'].astype(str), df['Y']))

        for drug, val in mapping.items():
            if drug in drug_to_idx and not pd.isna(val):
                y_vec[drug_to_idx[drug]] = val
        y_dict[task] = y_vec

    return X_features, y_dict

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import os

# %%
def train_hybrid_mtl_rf(X_train, y_train_dict, X_test, y_test_dict, reg_tasks, class_tasks):
    all_tasks = reg_tasks + class_tasks

    #tworzenie wspólnej macierzy
    Y_train_raw = np.hstack([y_train_dict[task] for task in all_tasks])
    Y_test_raw = np.hstack([y_test_dict[task] for task in all_tasks])

    Y_train_imputed = Y_train_raw.copy()
    Y_test_imputed = Y_test_raw.copy()

    print(">> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...")
    # Aby pozbyć się NaN, trenujemy szybkie modele bazowe.
    #Dla zadań regresyjnych używamy regresora, a dla klasyfikacyjnych klasyfikatora, wyciągając z niego prawdopodobieństwa, aby zachować ciągłość danych.
    for i, task in enumerate(all_tasks):
        known_train_idx = ~np.isnan(Y_train_raw[:, i])
        missing_train_idx = np.isnan(Y_train_raw[:, i])
        missing_test_idx = np.isnan(Y_test_raw[:, i])

        if task in reg_tasks:
            model_single = RandomForestRegressor(n_estimators=200, random_state=42, n_jobs=-1)
            model_single.fit(X_train[known_train_idx], Y_train_raw[known_train_idx, i])
            if np.any(missing_train_idx):
                Y_train_imputed[missing_train_idx, i] = model_single.predict(X_train[missing_train_idx])
            if np.any(missing_test_idx):
                Y_test_imputed[missing_test_idx, i] = model_single.predict(X_test[missing_test_idx])

        elif task in class_tasks:
            model_single = RandomForestClassifier(n_estimators=200, class_weight="balanced", random_state=42, n_jobs=-1)
            model_single.fit(X_train[known_train_idx], Y_train_raw[known_train_idx, i].astype(int))
            if np.any(missing_train_idx):
                Y_train_imputed[missing_train_idx, i] = model_single.predict_proba(X_train[missing_train_idx])[:, 1]
            if np.any(missing_test_idx):
                Y_test_imputed[missing_test_idx, i] = model_single.predict_proba(X_test[missing_test_idx])[:, 1]

    print(">> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...")
    mtl_model = RandomForestRegressor(n_estimators=1000, max_depth=25, max_features="sqrt", random_state=42, n_jobs=-1)
    mtl_model.fit(X_train, Y_train_imputed)

    Y_pred = mtl_model.predict(X_test)

    # Budowanie słownika dopasowanego do funkcji print/save
    metrics_summary = {}
    for i, task in enumerate(all_tasks):
        known_test_idx = ~np.isnan(Y_test_raw[:, i])
        true_y = Y_test_raw[known_test_idx, i]
        pred_y = Y_pred[known_test_idx, i]

        if task in reg_tasks:
            metrics_summary[task] = {
                "task_type": "regression",  # Flaga pomocnicza dla pętli
                "test_metrics": {
                    "rmse": np.sqrt(mean_squared_error(true_y, pred_y)),
                    "mae": mean_absolute_error(true_y, pred_y),
                    "r2": r2_score(true_y, pred_y)
                }
            }
        elif task in class_tasks:
            pred_classes = (pred_y >= 0.5).astype(int)
            true_classes = true_y.astype(int)
            metrics_summary[task] = {
                "task_type": "classification",  # Flaga pomocnicza dla pętli
                "test_metrics": {
                    "accuracy": accuracy_score(true_classes, pred_classes),
                    "f1": f1_score(true_classes, pred_classes, zero_division=0),
                    "auroc": roc_auc_score(true_classes, pred_y)
                }
            }

    return mtl_model, metrics_summary

# %% [markdown]
# # Test 1: hERG (Wang) + Lipophilicity (AstraZeneca)

# %% [markdown]
# Test pierwszy sprawdzający czy Lipophilicity (42000 związków) pomoże związanemu z nim CaCo-2 (Wang). Sprawdzamy czy MTL da lepsze wyniki niż STL.

# %%
# 1. Konfiguracja
reg_tasks = ['Lipophilicity_AstraZeneca']
class_tasks = ['hERG']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_herg, test_herg = load_split_pickle('hERG')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_lipo, emb_te_lipo = load_embeddings('Lipophilicity_AstraZeneca', train_lipo, test_lipo)
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)


df_train_list = [emb_tr_lipo, emb_tr_herg]
df_test_list = [emb_te_lipo, emb_te_herg]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_lipo.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="Lipophilicity + hERG"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:26:55] WARNING: not removing hydrogen atom without neighbors
# [11:26:55] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: Lipophilicity_AstraZeneca (REGRESSION)
#
# ========================================
#   RMSE     : 0.9740
#   MAE      : 0.7729
#   R²       : 0.3579
# ========================================
#
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8168
#   F1       : 0.8889
#   AUROC    : 0.8986
# ========================================

# %% [markdown]
# # Test2: hERG (Wang) + Lipophilicity (AstraZeneca) + Solubility (AqSolDB)

# %% [markdown]
# Sprawdzamy czy dołożenie kolejnego powiązanego zbioru poprawi wynik.

# %%
# 1. Konfiguracja
reg_tasks = ['Lipophilicity_AstraZeneca', 'Solubility_AqSolDB']
class_tasks = ['hERG']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_herg, test_herg = load_split_pickle('hERG')
train_sol, test_sol = load_split_pickle('Solubility_AqSolDB')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_lipo, emb_te_lipo = load_embeddings('Lipophilicity_AstraZeneca', train_lipo, test_lipo)
_, _, _, _, emb_tr_sol, emb_te_sol = load_embeddings('Solubility_AqSolDB', train_sol, test_sol)
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)


df_train_list = [emb_tr_lipo, emb_tr_sol, emb_tr_herg]
df_test_list = [emb_te_lipo, emb_te_sol, emb_te_herg]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_lipo.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="hERG + Lipophilicity + Solubility"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:27:55] WARNING: not removing hydrogen atom without neighbors
# [11:27:55] WARNING: not removing hydrogen atom without neighbors
# [11:27:55] WARNING: not removing hydrogen atom without neighbors
# [11:27:55] WARNING: not removing hydrogen atom without neighbors
# [11:27:55] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:56] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# [11:27:57] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: Lipophilicity_AstraZeneca (REGRESSION)
#
# ========================================
#   RMSE     : 1.0280
#   MAE      : 0.8236
#   R²       : 0.2847
# ========================================
#
# Endpoint: Solubility_AqSolDB (REGRESSION)
#
# ========================================
#   RMSE     : 1.4295
#   MAE      : 1.1091
#   R²       : 0.6234
# ========================================
#
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8321
#   F1       : 0.8972
#   AUROC    : 0.9085
# ========================================

# %% [markdown]
# # Test3: hERG (Wang) + Lipophilicity (AstraZeneca) + Solubility (AqSolDB) + VDss (Lombardo)

# %% [markdown]
# Sprawdzamy czy dołożenie kolejnego powiązanego zbioru poprawi wynik. Czy w jakimś momencie wyniki przestają się poprawiać?

# %%
# 1. Konfiguracja
reg_tasks = ['Lipophilicity_AstraZeneca', 'Solubility_AqSolDB', 'VDss_Lombardo']
class_tasks = ['hERG']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_herg, test_herg = load_split_pickle('hERG')
train_sol, test_sol = load_split_pickle('Solubility_AqSolDB')
train_vdss, test_vdss = load_split_pickle('VDss_Lombardo')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_lipo, emb_te_lipo = load_embeddings('Lipophilicity_AstraZeneca', train_lipo, test_lipo)
_, _, _, _, emb_tr_sol, emb_te_sol = load_embeddings('Solubility_AqSolDB', train_sol, test_sol)
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)
_, _, _, _, emb_tr_vdss, emb_te_vdss = load_embeddings('VDss_Lombardo', train_vdss, test_vdss)


df_train_list = [emb_tr_lipo, emb_tr_sol, emb_tr_vdss, emb_tr_herg]
df_test_list = [emb_te_lipo, emb_te_sol, emb_te_vdss, emb_te_herg]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_lipo.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="hERG + Lipophilicity + Solubility + VDss"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:31:33] WARNING: not removing hydrogen atom without neighbors
# [11:31:33] WARNING: not removing hydrogen atom without neighbors
# [11:31:33] WARNING: not removing hydrogen atom without neighbors
# [11:31:33] WARNING: not removing hydrogen atom without neighbors
# [11:31:33] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:34] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# [11:31:35] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: Lipophilicity_AstraZeneca (REGRESSION)
#
# ========================================
#   RMSE     : 1.1535
#   MAE      : 0.9433
#   R²       : 0.0994
# ========================================
#
# Endpoint: Solubility_AqSolDB (REGRESSION)
#
# ========================================
#   RMSE     : 1.7196
#   MAE      : 1.3794
#   R²       : 0.4551
# ========================================
#
# Endpoint: VDss_Lombardo (REGRESSION)
#
# ========================================
#   RMSE     : 7.6017
#   MAE      : 5.3933
#   R²       : -0.2337
# ========================================
#
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8168
#   F1       : 0.8899
#   AUROC    : 0.8930
# ========================================

# %% [markdown]
# # Test4: hERG (Wang) + VDss (Lombardo)

# %% [markdown]
# Sprawdzamy czy mały zbiór HIA pomoże CaCo-2 mniej niż większe zbiory z poprzednich testów. Jednocześnie sparwdzamy STL vs MTL.

# %%
# 1. Konfiguracja
reg_tasks = ['VDss_Lombardo']
class_tasks = ['hERG']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_herg, test_herg = load_split_pickle('hERG')
train_vdss, test_vdss = load_split_pickle('VDss_Lombardo')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)
_, _, _, _, emb_tr_vdss, emb_te_vdss = load_embeddings('VDss_Lombardo', train_vdss, test_vdss)


df_train_list = [emb_tr_vdss, emb_tr_herg]
df_test_list = [emb_te_vdss, emb_te_herg]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_herg.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="hERG + VDss"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:35:59] WARNING: not removing hydrogen atom without neighbors
# [11:36:00] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: VDss_Lombardo (REGRESSION)
#
# ========================================
#   RMSE     : 7.1359
#   MAE      : 4.9395
#   R²       : -0.0871
# ========================================
#
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8244
#   F1       : 0.8930
#   AUROC    : 0.8949
# ========================================

# %% [markdown]
# # Test5: hERG (Wang) + Solubility (AqSolDB)

# %% [markdown]
# Sprawdzamy czy duży zbiór Solubility pomoże innemu dużemu zbiorowi mniej niż małemu CaCo-2. Jednocześnie sprawdzamy STL vs MTL.

# %%
# 1. Konfiguracja
reg_tasks = ['Solubility_AqSolDB']
class_tasks = ['hERG']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_herg, test_herg = load_split_pickle('hERG')
train_sol, test_sol = load_split_pickle('Solubility_AqSolDB')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_sol, emb_te_sol = load_embeddings('Solubility_AqSolDB', train_sol, test_sol)
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)


df_train_list = [emb_tr_sol, emb_tr_herg]
df_test_list = [emb_te_sol, emb_te_herg]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_te_herg.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="hERG + Solubility"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:29] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# [11:36:30] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: Solubility_AqSolDB (REGRESSION)
#
# ========================================
#   RMSE     : 1.4024
#   MAE      : 1.0832
#   R²       : 0.6376
# ========================================
#
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8550
#   F1       : 0.9100
#   AUROC    : 0.8933
# ========================================

# %% [markdown]
# # Test6: Solubility (AqSolDB) + VDss (Lombardo)

# %% [markdown]
# Sprawdzamy czy zbiór niepowiązany pomoże zbiorowi CaCo-2.

# %%
# 1. Konfiguracja
reg_tasks = ['Solubility_AqSolDB', 'VDss_Lombardo']
class_tasks = []
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_sol, test_sol = load_split_pickle('Solubility_AqSolDB')
train_vdss, test_vdss = load_split_pickle('VDss_Lombardo')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_sol, emb_te_sol = load_embeddings('Solubility_AqSolDB', train_sol, test_sol)
_, _, _, _, emb_tr_vdss, emb_te_vdss = load_embeddings('VDss_Lombardo', train_vdss, test_vdss)


df_train_list = [emb_tr_sol, emb_tr_vdss]
df_test_list = [emb_te_sol, emb_te_vdss]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_sol.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="Solubility + VDss"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:04] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# [11:39:05] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: Solubility_AqSolDB (REGRESSION)
#
# ========================================
#   RMSE     : 1.6797
#   MAE      : 1.3386
#   R²       : 0.4801
# ========================================
#
# Endpoint: VDss_Lombardo (REGRESSION)
#
# ========================================
#   RMSE     : 7.6891
#   MAE      : 5.6559
#   R²       : -0.2622
# ========================================

# %% [markdown]
# # Test7: hERG (Wang) + AMES Mutagenicity

# %%
# 1. Konfiguracja
reg_tasks = []
class_tasks = ['hERG', 'AMES']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_herg, test_herg = load_split_pickle('hERG')
train_ames, test_ames = load_split_pickle('AMES')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)
_, _, _, _, emb_tr_ames, emb_te_ames = load_embeddings('AMES', train_ames, test_ames)


df_train_list = [emb_tr_herg, emb_tr_ames]
df_test_list = [emb_te_herg, emb_te_ames]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_herg.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="hERG + AMES"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:42:19] WARNING: not removing hydrogen atom without neighbors
# [11:42:20] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8397
#   F1       : 0.9014
#   AUROC    : 0.8825
# ========================================
#
# Endpoint: AMES (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8074
#   F1       : 0.8248
#   AUROC    : 0.8748
# ========================================

# %% [markdown]
# # Test8: hERG (Wang) + Lipophilicity (AstraZeneca) + Solubility (AqSolDB) + VDss (Lombardo) + AMES Mutagenicity

# %%
# 1. Konfiguracja
reg_tasks = ['Lipophilicity_AstraZeneca', 'Solubility_AqSolDB', 'VDss_Lombardo']
class_tasks = ['hERG', 'AMES']
all_tasks = reg_tasks + class_tasks
filepath = "mtl_results_kardiotoksycznosc_embeddings.txt"

# 2. Ładowanie oryginalnych podziałów pickle
train_lipo, test_lipo = load_split_pickle('Lipophilicity_AstraZeneca')
train_herg, test_herg = load_split_pickle('hERG')
train_sol, test_sol = load_split_pickle('Solubility_AqSolDB')
train_vdss, test_vdss = load_split_pickle('VDss_Lombardo')
train_ames, test_ames = load_split_pickle('AMES')

print(">> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...")
# Wywołujemy Twoją funkcję - ignorujemy czyste macierze (podłogi), bierzemy tabele z kolumną 'Drug'
_, _, _, _, emb_tr_lipo, emb_te_lipo = load_embeddings('Lipophilicity_AstraZeneca', train_lipo, test_lipo)
_, _, _, _, emb_tr_sol, emb_te_sol = load_embeddings('Solubility_AqSolDB', train_sol, test_sol)
_, _, _, _, emb_tr_herg, emb_te_herg = load_embeddings('hERG', train_herg, test_herg)
_, _, _, _, emb_tr_vdss, emb_te_vdss = load_embeddings('VDss_Lombardo', train_vdss, test_vdss)
_, _, _, _, emb_tr_ames, emb_te_ames = load_embeddings('AMES', train_ames, test_ames)


df_train_list = [emb_tr_lipo, emb_tr_sol, emb_tr_vdss, emb_tr_herg, emb_tr_ames]
df_test_list = [emb_te_lipo, emb_te_sol, emb_te_vdss, emb_te_herg, emb_te_ames]

print(">> 2. Tworzenie podręcznego słownika embeddingów...")
# Ustalamy nazwy kolumn z embeddingami
feature_cols = [c for c in emb_tr_lipo.columns if c.startswith('emb_')]

# Łączymy wszystkie załadowane dane w jeden słownik: {SMILES: wektor_liczb}
all_loaded_dfs = df_train_list + df_test_list
emb_dict = {}
for df in all_loaded_dfs:
    for drug, emb_vector in zip(df['Drug'].astype(str), df[feature_cols].values):
        emb_dict[drug] = emb_vector

# ==============================================================================
# POPRAWIONY FEATURIZER (Szuka po SMILES w słowniku, ignoruje brak kolumn emb_ w df_temp)
# ==============================================================================
featurizer = lambda df: (np.array([emb_dict.get(str(smiles), np.zeros(len(feature_cols))) for smiles in df['Drug']]), None)
# ==============================================================================

print(">> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...")
X_train_mtl, y_train_dict = prepare_mtl_data_final(df_train_list, all_tasks, featurizer)
X_test_mtl, y_test_dict   = prepare_mtl_data_final(df_test_list, all_tasks, featurizer)

print(">> Uruchamianie hybrydowego treningu Multi-Task Random Forest...")
mtl_model, metrics = train_hybrid_mtl_rf(
    X_train_mtl, y_train_dict,
    X_test_mtl, y_test_dict,
    reg_tasks, class_tasks
)

print("\n>>> RAPORTY KOŃCOWYCH METRYK <<<")
for task_name, task_data in metrics.items():
    task_type = task_data["task_type"]

    print(f"Endpoint: {task_name} ({task_type.upper()})")
    print_metrics(task_data, task=task_type)

    save_metrics(
        metrics=task_data,
        dataset_name=task_name,
        filepath=filepath,
        task=task_type,
        endpoint_group_name="hERG + Lipophilicity + Solubility + VDss + AMES"
    )
# Out:
# >> 1. Ładowanie embeddingów za pomocą Twojej funkcji load_embeddings...
# >> 2. Tworzenie podręcznego słownika embeddingów...
# >> 3. Przygotowywanie zintegrowanych zbiorów danych MTL...
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:49] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:50] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:51] WARNING: not removing hydrogen atom without neighbors
# [11:42:52] WARNING: not removing hydrogen atom without neighbors
# [11:42:52] WARNING: not removing hydrogen atom without neighbors
# [11:42:52] WARNING: not removing hydrogen atom without neighbors
# >> Uruchamianie hybrydowego treningu Multi-Task Random Forest...
# >> Krok 1: Imputacja brakujących wartości (Pseudo-labeling)...
# >> Krok 2: Uruchamianie treningu wspólnego modelu Multi-Task Random Forest...
#
# >>> RAPORTY KOŃCOWYCH METRYK <<<
# Endpoint: Lipophilicity_AstraZeneca (REGRESSION)
#
# ========================================
#   RMSE     : 1.1616
#   MAE      : 0.9525
#   R²       : 0.0867
# ========================================
#
# Endpoint: Solubility_AqSolDB (REGRESSION)
#
# ========================================
#   RMSE     : 1.7304
#   MAE      : 1.3889
#   R²       : 0.4482
# ========================================
#
# Endpoint: VDss_Lombardo (REGRESSION)
#
# ========================================
#   RMSE     : 7.7547
#   MAE      : 5.5379
#   R²       : -0.2838
# ========================================
#
# Endpoint: hERG (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.8168
#   F1       : 0.8889
#   AUROC    : 0.9054
# ========================================
#
# Endpoint: AMES (CLASSIFICATION)
#
# ========================================
#   Accuracy : 0.7249
#   F1       : 0.7072
#   AUROC    : 0.8276
# ========================================
